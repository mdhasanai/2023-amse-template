# %% [markdown]
# # Data Exploration
#
# In this notebook describe your data exploration steps.

# %% [markdown]
# ## Install dependencies

# %%
# %pip install pandas
# %pip install sqlite3
# %pip install SQLAlchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load data

# %%
import pandas as pd
import sqlite3 as db
conn = db.connect('./data/database/data.db')

# Setting queries for loading data
query_1 = f"SELECT * FROM table1"
query_2 = f"SELECT * FROM table2"

# load data from the database into pandas dataframe
df_1 = pd.read_sql_query(query_1, conn)
df_2 = pd.read_sql_query(query_2, conn)

# %% [markdown]
# ### Look at the first rows

# %%
df_1.head(10)
# Out:
#                                     betreiber  art_der_ladeeinrichung
# 0  Technische Werke Schussental GmbH & Co. KG   Normalladeeinrichtung  \
# 1  Technische Werke Schussental GmbH & Co. KG   Normalladeeinrichtung
# 2  Technische Werke Schussental GmbH & Co. KG   Normalladeeinrichtung
# 3  Technische Werke Schussental GmbH & Co. KG   Normalladeeinrichtung
# 4  Technische Werke Schussental GmbH & Co. KG   Normalladeeinrichtung
# 5  Technische Werke Schussental GmbH & Co. KG   Normalladeeinrichtung
# 6  Technische Werke Schussental GmbH & Co. KG   Normalladeeinrichtung
# 7                                        Lidl  Schnellladeeinrichtung
# 8                               Citywatt GmbH  Schnellladeeinrichtung
# 9                               Citywatt GmbH  Schnellladeeinrichtung
#
#    anzahl_ladepunkte  anschlussleistung                         steckertypen1
# 0                  2               22.0                    AC Steckdose Typ 2  \
# ...

# %%
df_2.head(10)
# Out:
#                        Betreiber                  Straße Hausnummer
# 0          Albwerk GmbH & Co. KG          Ennabeurer Weg          0  \
# 1                        smopi®                Albstraße         14
# 2          Albwerk GmbH & Co. KG  Parkplatz Campingplatz          0
# 3   EnBW mobility+ AG und Co.KG              Hauptstraße        91c
# 4               SWU Energie GmbH              Sterngasse          6
# 5  Physiotherapie im Stadtgarten           Lange Strasse         15
# 6                   Solarcollect          Eichlesstrasse         18
# 7   EnBW mobility+ AG und Co.KG                 Karlstr.         45
# 8   EnBW mobility+ AG und Co.KG                Flurstück        313
# 9   EnBW mobility+ AG und Co.KG                Flurstück        313
#
#   Adresszusatz  Postleitzahl                   Ort         Bundesland
# 0         None         72535           Heroldstatt  Baden-Württemberg  \
# 1         None         72535           Heroldstatt  Baden-Württemberg
# ...

# %% [markdown]
# ### Data exploration
# Print some basic information about the data. Your data exploration would continue here.

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36770 entries, 0 to 36769
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   betreiber               36770 non-null  object
#  1   art_der_ladeeinrichung  36770 non-null  object
#  2   anzahl_ladepunkte       36770 non-null  int64
#  3   anschlussleistung       36770 non-null  float64
#  4   steckertypen1           36770 non-null  object
#  5   steckertypen2           31111 non-null  object
#  6   steckertypen3           2233 non-null   object
#  7   steckertypen4           1132 non-null   object
#  8   p1_kw                   36770 non-null  float64
#  9   p2_kw                   31129 non-null  float64
#  10  p3_kw                   2233 non-null   float64
#  11  p4_kw                   1131 non-null   float64
#  12  kreis_kreisfreie_stadt  36770 non-null  object
#  13  ort                     36770 non-null  object
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42995 entries, 0 to 42994
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Betreiber               42995 non-null  object
#  1   Straße                  42995 non-null  object
#  2   Hausnummer              42995 non-null  object
#  3   Adresszusatz            6115 non-null   object
#  4   Postleitzahl            42995 non-null  int64
#  5   Ort                     42995 non-null  object
#  6   Bundesland              42995 non-null  object
#  7   Kreis/kreisfreie Stadt  42995 non-null  object
#  8   Breitengrad             42995 non-null  float64
#  9   Längengrad              42995 non-null  float64
#  10  Inbetriebnahmedatum     42995 non-null  object
#  11  Anschlussleistung       42995 non-null  float64
#  12  Art der Ladeeinrichung  42995 non-null  object
#  13  Anzahl Ladepunkte       42995 non-null  int64
# ...

# %%
df_1["p1_kw"].describe()
# Out:
# count    36770.000000
# mean        37.648928
# std         58.958237
# min          1.000000
# 25%         22.000000
# 50%         22.000000
# 75%         22.000000
# max        360.000000
# Name: p1_kw, dtype: float64

# %%
df_1["p2_kw"].describe()
# Out:
# count    31129.000000
# mean        38.365378
# std         58.080733
# min          2.000000
# 25%         22.000000
# 50%         22.000000
# 75%         22.000000
# max        360.000000
# Name: p2_kw, dtype: float64

# %%
df_2["P1 [kW]"].describe()
# Out:
# count    42995.000000
# mean        43.619511
# std         70.511931
# min          1.000000
# 25%         22.000000
# 50%         22.000000
# 75%         22.000000
# max        360.000000
# Name: P1 [kW], dtype: float64

# %%
df_2["P2 [kW]"].describe()
# Out:
# count    34668.000000
# mean        40.688187
# std         63.300356
# min          2.000000
# 25%         22.000000
# 50%         22.000000
# 75%         22.000000
# max        360.000000
# Name: P2 [kW], dtype: float64

# %% [markdown]
# ### where is the most charging station available?

# %%
most_common_postcode = df_1['postleitzahl'].value_counts().idxmax()
print("The most common postal code in data source 1 is:", most_common_postcode)

most_common_postcode = df_2['Postleitzahl'].value_counts().idxmax()
print("The most common postal code in data source 2 is:", most_common_postcode)
# Out:
# The most common postal code in data source 1 is: 80937
# The most common postal code in data source 2 is: 80937
